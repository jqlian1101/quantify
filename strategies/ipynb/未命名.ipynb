# %%
import pandas as pd
df = pd.DataFrame({'a':[1,2,3], 'b':[4,5,6], 'c':[7,8,9]})
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.rename(columns={'a':'A'})
# Out:
#    A  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
import akshare as ak

get_roll_yield_bar_df = ak.get_roll_yield_bar(type_method="date", var="RB", start_day="20210618", end_day="20210718", plot=True)
print(get_roll_yield_bar_df)
# Out:
# /opt/anaconda3/envs/quantify/lib/python3.7/site-packages/akshare/futures/futures_roll_yield.py:68: UserWarning: 20210619非交易日
#   warnings.warn("%s非交易日" % date.strftime("%Y%m%d"))
# /opt/anaconda3/envs/quantify/lib/python3.7/site-packages/akshare/futures/futures_roll_yield.py:68: UserWarning: 20210620非交易日
#   warnings.warn("%s非交易日" % date.strftime("%Y%m%d"))
# /opt/anaconda3/envs/quantify/lib/python3.7/site-packages/akshare/futures/futures_roll_yield.py:68: UserWarning: 20210626非交易日
#   warnings.warn("%s非交易日" % date.strftime("%Y%m%d"))
# /opt/anaconda3/envs/quantify/lib/python3.7/site-packages/akshare/futures/futures_roll_yield.py:68: UserWarning: 20210627非交易日
#   warnings.warn("%s非交易日" % date.strftime("%Y%m%d"))
# /opt/anaconda3/envs/quantify/lib/python3.7/site-packages/akshare/futures/futures_roll_yield.py:68: UserWarning: 20210703非交易日
#   warnings.warn("%s非交易日" % date.strftime("%Y%m%d"))
# ...

# %%
ak.__doc__
# Out:
# 'AKShare 是基于 Python 的开源财经数据接口库, 实现对股票, 期货, 期权, 基金, 债券, 外汇等金\n融产品的量价数据, 基本面数据和另类数据从数据采集, 数据清洗到数据下载的工具, 满足金融数据科学\n家, 数据科学爱好者在数据获取方面的需求. 它的特点是利用 AKShare 获取的是基于可信任数据源\n发布的原始数据, 广大数据科学家可以利用原始数据进行再加工, 从而得出科学的结论.'

# %%
stock_us_daily_df = ak.stock_us_daily(symbol="AMZN")  # Get U.S. stock Amazon's price info
print(stock_us_daily_df)
# Out:
#                  open       high        low      close     volume
# date
# 1997-05-15    29.2500    30.0000    23.1300    23.5000  6013000.0
# 1997-05-16    23.6300    23.7500    20.5000    20.7500  1225000.0
# 1997-05-19    21.1300    21.2500    19.5000    20.5000   508900.0
# 1997-05-20    20.7500    21.0000    19.6300    19.6300   455600.0
# 1997-05-21    19.6300    19.7500    16.5000    17.1300  1571100.0
# ...               ...        ...        ...        ...        ...
# 2021-07-21  3576.3750  3586.4500  3543.6416  3585.2000  2318657.0
# 2021-07-22  3587.2300  3640.0200  3582.2700  3638.0300  3264589.0
# 2021-07-23  3640.0000  3666.1101  3622.0400  3656.6399  2436066.0
# 2021-07-26  3673.1699  3712.0801  3647.2500  3699.8201  2899535.0
# 2021-07-27  3698.5000  3698.5000  3586.1499  3626.3899  4131890.0
#
# [6088 rows x 5 columns]
